# %%
import pandas as pd

# %%
df = pd.read_excel("data\Prestamos_Data_Alumnos_v5.xlsx")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\macia\AppData\Local\Temp\ipykernel_10848\350998259.py:1: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_excel("data\Prestamos_Data_Alumnos_v5.xlsx")

# %%
df.head()
# Out:
#        ID  Edad  Ingresos  Monto_Inicial  Scoring_Crediticio  Meses_Empleo  \
# 0  O77MPJ    26   19153.0           6973                 706           9.0
# 1  6B4H6E    22   16000.0          10000                 769          22.0
# 2  VKTUXP    33   38308.0          16474                 699          70.0
# 3  5P9OVL    51   51271.0          40770                 812         309.0
# 4  KG9CT9    34   56572.0          73978                 763          86.0
#
#    Num_Creditos  Ratio_Interes  Duracion  Ratio_Deuda_Ingresos  \
# 0             1          19.05      36.0                  0.10
# 1             1           8.96      48.0                  0.32
# 2             3          14.07      36.0                  0.20
# 3             1          12.66      12.0                  0.36
# 4             1          13.91      60.0                  0.55
#
#               Estudios Tipo_Jornada_Laboral Estado_Civil  Posesion_Hipoteca  \
# 0  Grado Universitario     Jornada completa      Soltero                0.0
# 1              Escolar          Desempleado      Soltero                1.0
# 2               Máster     Jornada completa       Casado                1.0
# 3  Grado Universitario     Jornada completa       Casado                0.0
# 4               Máster       Tiempo parcial      Soltero                0.0
#
#    Personas_Cargo  Proposito  Fiador  Impago   Prima
# 0             1.0  Automóvil     1.0       1  130.83
# 1             1.0   Vivienda     0.0       0   65.85
# 2             1.0   Vivienda     0.0       0  260.60
# 3             1.0   Vivienda     1.0       0  221.02
# 4             0.0  Educación     0.0       0  800.00

# %%
df.info
# Out:
# <bound method DataFrame.info of             ID  Edad  Ingresos  Monto_Inicial  Scoring_Crediticio  \
# 0       O77MPJ    26   19153.0           6973                 706
# 1       6B4H6E    22   16000.0          10000                 769
# 2       VKTUXP    33   38308.0          16474                 699
# 3       5P9OVL    51   51271.0          40770                 812
# 4       KG9CT9    34   56572.0          73978                 763
# ...        ...   ...       ...            ...                 ...
# 510699  MY63P5    28   17390.0           5000                 744
# 510700  6903JQ    42   33486.0          33048                 760
# 510701  EPB8QX    64   40369.0          40000                 680
# 510702  R1QRKW    35   30915.0         130966                 739
# 510703  Q90VE4    28   25765.0           6515                 788
#
#         Meses_Empleo  Num_Creditos  Ratio_Interes  Duracion  \
# 0                9.0             1          19.05      36.0
# 1               22.0             1           8.96      48.0
# 2               70.0             3          14.07      36.0
# 3              309.0             1          12.66      12.0
# 4               86.0             1          13.91      60.0
# ...              ...           ...            ...       ...
# 510699          92.0             3          16.12      12.0
# 510700         206.0             1           9.09      24.0
# 510701         447.0             2           7.75      12.0
# 510702         134.0             2          10.22      24.0
# 510703          20.0             1           8.29      24.0
#
#         Ratio_Deuda_Ingresos             Estudios Tipo_Jornada_Laboral  \
# 0                       0.10  Grado Universitario     Jornada completa
# 1                       0.32              Escolar          Desempleado
# 2                       0.20               Máster     Jornada completa
# 3                       0.36  Grado Universitario     Jornada completa
# 4                       0.55               Máster       Tiempo parcial
# ...                      ...                  ...                  ...
# 510699                  0.10              Escolar          Desempleado
# 510700                  0.31  Grado Universitario             Autónomo
# 510701                  0.19              Escolar     Jornada completa
# 510702                  0.55              Escolar     Jornada completa
# 510703                  0.22  Grado Universitario       Tiempo parcial
#
#        Estado_Civil  Posesion_Hipoteca  Personas_Cargo  Proposito  Fiador  \
# 0           Soltero                0.0             1.0  Automóvil     1.0
# 1           Soltero                1.0             1.0   Vivienda     0.0
# 2            Casado                1.0             1.0   Vivienda     0.0
# 3            Casado                0.0             1.0   Vivienda     1.0
# 4           Soltero                0.0             0.0  Educación     0.0
# ...             ...                ...             ...        ...     ...
# 510699      Soltero                0.0             0.0   Negocios     0.0
# 510700   Divorciado                0.0             0.0  Automóvil     0.0
# 510701       Casado                1.0             1.0   Negocios     1.0
# 510702       Casado                1.0             0.0  Educación     0.0
# 510703      Soltero                0.0             0.0   Negocios     0.0
#
#         Impago   Prima
# 0            1  130.83
# 1            0   65.85
# 2            0  260.60
# 3            0  221.02
# 4            0  800.00
# ...        ...     ...
# 510699       0   26.80
# 510700       0  172.41
# 510701       1  207.42
# 510702       0  580.00
# 510703       0   17.01
#
# [510704 rows x 19 columns]>

# %%
df.dtypes
# Out:
# ID                       object
# Edad                      int64
# Ingresos                float64
# Monto_Inicial             int64
# Scoring_Crediticio        int64
# Meses_Empleo            float64
# Num_Creditos              int64
# Ratio_Interes           float64
# Duracion                float64
# Ratio_Deuda_Ingresos    float64
# Estudios                 object
# Tipo_Jornada_Laboral     object
# Estado_Civil             object
# Posesion_Hipoteca       float64
# Personas_Cargo          float64
# Proposito                object
# Fiador                  float64
# Impago                    int64
# Prima                   float64
# dtype: object

# %%
df['Proposito'].duplicated().value_counts()
# Out:
# <bound method IndexOpsMixin.value_counts of 0         False
# 1         False
# 2          True
# 3          True
# 4         False
#           ...
# 510699     True
# 510700     True
# 510701     True
# 510702     True
# 510703     True
# Name: Proposito, Length: 510704, dtype: bool>

# %%
copia = df.copy()

# %%
copia.shape

# %%
copia = copia[copia["Proposito"] == "Vivienda"]
copia.head()
# Out:
#         ID  Edad  Ingresos  Monto_Inicial  Scoring_Crediticio  Meses_Empleo  \
# 1   6B4H6E    22   16000.0          10000                 769          22.0
# 2   VKTUXP    33   38308.0          16474                 699          70.0
# 3   5P9OVL    51   51271.0          40770                 812         309.0
# 10  YL0W8G    30   31923.0          36707                 813          43.0
# 13  YP8WTV    28   27373.0          86981                 765          60.0
#
#     Num_Creditos  Ratio_Interes  Duracion  Ratio_Deuda_Ingresos  \
# 1              1           8.96      48.0                  0.32
# 2              3          14.07      36.0                  0.20
# 3              1          12.66      12.0                  0.36
# 10             1           8.96      24.0                  0.32
# 13             2          10.07      48.0                  0.55
#
#                Estudios Tipo_Jornada_Laboral Estado_Civil  Posesion_Hipoteca  \
# 1               Escolar          Desempleado      Soltero                1.0
# 2                Máster     Jornada completa       Casado                1.0
# 3   Grado Universitario     Jornada completa       Casado                0.0
# 10  Grado Universitario     Jornada completa       Casado                0.0
# 13              Escolar     Jornada completa      Soltero                0.0
#
#     Personas_Cargo Proposito  Fiador  Impago   Prima
# 1              1.0  Vivienda     0.0       0   65.85
# 2              1.0  Vivienda     0.0       0  260.60
# 3              1.0  Vivienda     1.0       0  221.02
# 10             1.0  Vivienda     0.0       0  125.00
# 13             1.0  Vivienda     0.0       0  800.00

# %%
copia['Proposito'].value_counts()
# Out:
# <bound method IndexOpsMixin.value_counts of 1         Vivienda
# 2         Vivienda
# 3         Vivienda
# 10        Vivienda
# 13        Vivienda
#             ...
# 510670    Vivienda
# 510671    Vivienda
# 510689    Vivienda
# 510691    Vivienda
# 510694    Vivienda
# Name: Proposito, Length: 101899, dtype: object>

# %%
duplicados=copia[copia.duplicated()]
duplicados

# %%
id_dup=copia[copia['ID']=='AIJ783']
id_dup

# %%
copia.isna().sum()
# Out:
# ID                      0
# Edad                    0
# Ingresos                0
# Monto_Inicial           0
# Scoring_Crediticio      0
# Meses_Empleo            0
# Num_Creditos            0
# Ratio_Interes           0
# Duracion                1
# Ratio_Deuda_Ingresos    1
# Estudios                2
# Tipo_Jornada_Laboral    1
# Estado_Civil            0
# Posesion_Hipoteca       2
# Personas_Cargo          1
# Proposito               0
# Fiador                  1
# Impago                  0
# Prima                   1
# dtype: int64

# %%
media_duracion = copia['Duracion'].mean()

copia['Duracion']=copia['Duracion'].fillna(media_duracion)

copia['Duracion'] = copia['Duracion'].isna().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\macia\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Duracion'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 media_duracion = copia['Duracion'].mean()
#       3 copia['Duracion']=copia['Duracion'].fillna(media_duracion)
#       5 copia['Duracion'] = copia['Duracion'].isna().sum()
#
# File c:\Users\macia\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File c:\Users\macia\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# File c:\Users\macia\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Duracion'

# %%
copia["Estudios"]
